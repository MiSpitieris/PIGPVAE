# %%
import os
import sys

import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import pandas as pd
import copy
from torch.utils.data import Dataset, DataLoader,random_split, Subset
from tqdm import tqdm

sys.path.append(os.path.abspath('..'))
from Models.PIVAE_pendulum import PIVAE
from physics import SimplePendulumSolver
from VAE_utils import q_net
from VAE_utils import vae_loss as KL_div

# %%
class PendulumDataset(Dataset):
    def __init__(self, df):
        self.df = df
        self.unique_intervals = df['interval'].unique()

    def __len__(self):
        return len(self.unique_intervals)

    def __getitem__(self, idx):
        batch = self.unique_intervals[idx]
        id = self.df['interval'] == batch
        theta = torch.tensor(self.df[id]['theta'].to_numpy(), dtype=torch.float32)
        t = torch.tensor(self.df[id]['t'].to_numpy(), dtype=torch.float32)  # Normalize time
        # t = torch.tensor(self.df[id]['t'].to_numpy(), dtype=torch.float32)  # Normalize time
        # Concatenate theta and t as input batch
        x_batch = torch.cat((theta.unsqueeze(1), t.unsqueeze(1)), axis=1)
        return x_batch # Also return omega for plotting

# Load the dataset
df_damped = pd.read_csv("../Data/damped_pendulum_data.csv")
df_damped['interval'] = df_damped['omega'].astype('category').cat.codes
df_damped['theta'] = df_damped['theta']
# df_damped = df_damped[df_damped['t'] <= 10]

dataset = PendulumDataset(df_damped)
dataloader = DataLoader(dataset)
train_ratio = 0.7
test_ratio = 1-train_ratio

# Calculate split sizes
total_size = len(dataset)
train_size = int(train_ratio * total_size)
test_size = total_size - train_size

seed = 42
generator = torch.Generator().manual_seed(seed)

# Split the dataset
train_subset, test_subset = random_split(
    dataset,
    [train_size, test_size],
    generator=generator
)
train_loader = DataLoader(train_subset, batch_size=1, shuffle=False)
val_loader = DataLoader(test_subset, batch_size=1, shuffle=False)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 6))

for i, x_batch in enumerate(train_loader):
    # x_batch has shape (1, N, 2) if batch_size=1
    x_batch = x_batch.squeeze(0)  # Now shape is (N, 2)

    # Extract theta and time
    theta_values = x_batch[:, 0].numpy()
    time_values = x_batch[:, 1].numpy()  # * 10  # Reverse normalization

    plt.plot(time_values, theta_values, label=f'Trajectory #{i}')

plt.xlabel("Time")
plt.ylabel("Theta")
plt.title("Pendulum Simulations")
plt.legend()
plt.grid()
plt.show()

# %%
# Set the variables to be selected from the dataframe
torch.manual_seed(0)
model = PIVAE(hidden_layers=[10], 
              activation=nn.Tanh(),
              mu_prior=torch.tensor(0),
              var_prior=torch.tensor(2.0))
# Initialize model parameters and optimizer
pars = model.parameters()
opt = torch.optim.Adam(pars, lr=0.0001)

# Lists to store loss values
l_loss, KL, mse = [], [], []

# Set beta value and number of epochs
beta_phy = 1
# beta_phy = 0.1
num_epochs = 200

l_loss, KL, mse = model.fit(dataloader, opt, beta_phy, num_epochs)
# Out:
# Progress: Epoch 40/200 | Loss=0.1341, KL=0.0252, MSE=0.1089
# Progress: Epoch 80/200 | Loss=0.1388, KL=0.0221, MSE=0.1166
# Progress: Epoch 120/200 | Loss=0.1256, KL=0.0187, MSE=0.1069
# Progress: Epoch 160/200 | Loss=0.1792, KL=0.0151, MSE=0.1641
# Progress: Epoch 200/200 | Loss=0.1084, KL=0.0181, MSE=0.0903

# %%
fig, axs = plt.subplots(1, 3, figsize=(15, 5))
# Loss plot
epochs = range(num_epochs)
axs[0].plot(epochs, l_loss, 'r-')
axs[0].set_title('Loss')
axs[0].set_xlabel('Epoch')
# axs[0].set_ylabel('Loss')

# MSE plot
axs[1].plot(epochs, mse, 'g-')
axs[1].set_title('MSE')
axs[1].set_xlabel('Epoch')
# axs[1].set_ylabel('MSE')

# KL Divergence plot
axs[2].plot(epochs, KL, 'b-')
axs[2].set_title('KL')
axs[2].set_xlabel('Epoch')
# axs[2].set_ylabel('KL')

plt.tight_layout()
plt.show()

# %%
x_hat, mu, var = {}, {}, {}
for x_batch in dataset:
    with torch.no_grad():
        x_batch = x_batch.squeeze(0)  # Remove the batch dimension if necessary
        x_hat[x_batch], mu[x_batch], var[x_batch] = model(x_batch)

mu_tensor = torch.cat([mu[batch] for batch in mu.keys()], dim=0)
var_tensor = torch.cat([var[batch] for batch in var.keys()], dim=0)
mu_PIVAE_post = mu_tensor.mean()
var_PIVAE_post = var_tensor.mean()

# %%
mu_PIVAE_post
# Out:
# tensor(-0.1389)

# %%
var_PIVAE_post
# Out:
# tensor(1.5810)

# %%
torch.tensor(time_values)
# Out:
# tensor([ 0.0000,  0.1010,  0.2020,  0.3030,  0.4040,  0.5051,  0.6061,  0.7071,
#          0.8081,  0.9091,  1.0101,  1.1111,  1.2121,  1.3131,  1.4141,  1.5152,
#          1.6162,  1.7172,  1.8182,  1.9192,  2.0202,  2.1212,  2.2222,  2.3232,
#          2.4242,  2.5253,  2.6263,  2.7273,  2.8283,  2.9293,  3.0303,  3.1313,
#          3.2323,  3.3333,  3.4343,  3.5354,  3.6364,  3.7374,  3.8384,  3.9394,
#          4.0404,  4.1414,  4.2424,  4.3434,  4.4444,  4.5455,  4.6465,  4.7475,
#          4.8485,  4.9495,  5.0505,  5.1515,  5.2525,  5.3535,  5.4545,  5.5556,
#          5.6566,  5.7576,  5.8586,  5.9596,  6.0606,  6.1616,  6.2626,  6.3636,
#          6.4646,  6.5657,  6.6667,  6.7677,  6.8687,  6.9697,  7.0707,  7.1717,
#          7.2727,  7.3737,  7.4747,  7.5758,  7.6768,  7.7778,  7.8788,  7.9798,
#          8.0808,  8.1818,  8.2828,  8.3838,  8.4848,  8.5859,  8.6869,  8.7879,
#          8.8889,  8.9899,  9.0909,  9.1919,  9.2929,  9.3939,  9.4949,  9.5960,
# ...

# %%
# y0_val = torch.arange(-1,1,0.05,dtype=torch.float32)
y0_val = torch.ones(10)*0.5
gen_data, k_samples = model.generate(mu_PIVAE_post, var_PIVAE_post, y0_val, torch.tensor(time_values))

# %%
plt.figure()  # Create a new figure
for i, data_tensor in enumerate(gen_data):
    # Squeeze out the last dimension from [100, 1] to [100]
    y_np = data_tensor.squeeze(-1).cpu().numpy()
    plt.plot(time_values, y_np, label=f"gen_{i}")

plt.xlabel("Time")
plt.ylabel("Generated Value")
plt.legend()
plt.show()

# %%
from scipy.stats import lognorm

def plot_single_lognormal(mu, sigma, x_range=(0.01, 20), num_points=1000):
    """
    Plot a single log-normal distribution.

    Parameters:
        mu: Mean of the underlying normal distribution.
        sigma: Standard deviation of the underlying normal distribution.
        x_range: Tuple specifying the range of x values (start, end).
        num_points: Number of points in the x range.
    """
    x = np.linspace(x_range[0], x_range[1], num_points)
    pdf = lognorm.pdf(x, s=sigma, scale=np.exp(mu))
    
    plt.figure(figsize=(8, 5))
    plt.plot(x, pdf, label=f'Lognormal(mu={mu}, sigma={sigma})')
    plt.title('Prior')
    plt.xlabel('x')
    plt.ylabel('Density')
    plt.legend()
    plt.grid(True)
    plt.show()

# Example usage:
plot_single_lognormal(mu=1.7, sigma=1)

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

# Set parameters for the normal distribution
mu = mu_PIVAE_post.numpy()  # Mean of the normal distribution
sigma = 1  # Standard deviation of the normal distribution

# Generate samples from the normal distribution
num_samples = 10000
normal_samples = np.random.normal(mu, sigma, num_samples)

# Transform normal samples to log-normal samples
log_normal_samples = np.exp(normal_samples)

# Plot the histograms
fig, ax = plt.subplots(1, 2, figsize=(12, 5))

# Plot the normal distribution
ax[0].hist(normal_samples, bins=50, density=True, alpha=0.6, color='b', label="Normal Samples")
x_vals = np.linspace(min(normal_samples), max(normal_samples), 100)
ax[0].plot(x_vals, stats.norm.pdf(x_vals, mu, sigma), 'r', label="Normal PDF")
ax[0].set_title("Normal Distribution")
ax[0].legend()

# Plot the log-normal distribution
ax[1].hist(log_normal_samples, bins=50, density=True, alpha=0.6, color='g', label="Log-Normal Samples")
x_vals = np.linspace(min(log_normal_samples), max(log_normal_samples), 100)
ax[1].plot(x_vals, stats.lognorm.pdf(x_vals, s=sigma, scale=np.exp(mu)), 'r', label="Log-Normal PDF")
ax[1].set_title("Log-Normal Distribution")
ax[1].legend()

plt.show()

# %%
original, reconstructed = model.reconstruct(dataset)

# %%
num_series = original.shape[0]

# Create subplots
fig, axes = plt.subplots(nrows=5, ncols=4, figsize=(15, 10), sharex=True, sharey=True)
axes = axes.flatten()  # Flatten axes array for easy iteration

# Plot each time series
for i in range(num_series):
    axes[i].plot(original[i], label="Original", color="blue", alpha=0.7)
    axes[i].plot(reconstructed[i], label="Reconstructed", color="red", linestyle="dashed", alpha=0.7)
    axes[i].set_title(f"Series {i+1}")
    axes[i].legend()

# Adjust layout
plt.tight_layout()
plt.show()

# %%
import tsgm
ns = total_size
torch.manual_seed(3)
#T0 = torch.linspace(-1.5,1.5,ns)
y0_val = torch.linspace(-1,1,ns)
generated_data, k_samples = model.generate(mu_PIVAE_post, var_PIVAE_post, y0_val, torch.tensor(time_values))
# Ts,T0,k_values
mmd_metric = tsgm.metrics.MMDMetric()
Gd = torch.stack(generated_data)
full_data = DataLoader(dataset)
original_data_list = []

# Iterate through the DataLoader
for batch in full_data:
    original_data_list.append(batch[0][:,0])

# Stack to create a tensor of shape [total_samples, 24, 1]
original_data = torch.stack(original_data_list)
original_data = original_data.unsqueeze(-1)
# Check the shape
# print(original_data.shape)
mmd_metric(original_data, Gd)
# Out:
# 0.19706210028380156
