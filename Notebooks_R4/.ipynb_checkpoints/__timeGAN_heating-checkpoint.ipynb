# %%
# Import necessary libraries
import torch
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from torch.utils.data import Dataset, DataLoader


import tsgm
from sklearn.preprocessing import MinMaxScaler

# %%
file_path = '../Data/RICO4_Dataset_processed.hdf'
df = pd.read_hdf(file_path)

# %%
df_c = df[df['temp_change_class'] == 'h']
def select_points(group):
    return group.iloc[::10]  # Select every 10th row
df_c = df_c.groupby('Scheduler Step').apply(select_points).reset_index(drop=True)
# Out:
# /var/folders/46/30710m094qv2_dhfs08nzzd00000gn/T/ipykernel_84261/215021774.py:4: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_c = df_c.groupby('Scheduler Step').apply(select_points).reset_index(drop=True)

# %%
df_c = df_c[['B.RTD1','time_within_interval','interval']]

# %%
# Initialize a list to collect each time series sequence
sequences = []

# Set the desired sequence length
seq_len = 24

# Group by each unique interval
for _, group in df_c.groupby('interval'):
    # Select B.RTD1 values as the time series data
    sequence = group['B.RTD1'].values
    
    # Truncate or pad the sequence to ensure it has exactly 24 time steps
    if len(sequence) >= seq_len:
        sequence = sequence[:seq_len]
    else:
        sequence = np.pad(sequence, (0, seq_len - len(sequence)), 'constant', constant_values=0)
    
    # Append the sequence as a new entry in the list
    sequences.append(sequence)

# Convert the list of sequences to a DataFrame
df_sequences = pd.DataFrame(sequences)
sequences_array = df_sequences.to_numpy()
sequences_array = sequences_array.reshape((sequences_array.shape[0], sequences_array.shape[1], 1))
print(sequences_array.shape) 
data=sequences_array
# Out:
# (31, 24, 1)

# %%
scaler = tsgm.utils.TSFeatureWiseScaler()        
scaled_data = scaler.fit_transform(data)

# Plot for the first feature
num_sequences = scaled_data.shape[0]

plt.figure(figsize=(12, 8))
for i in range(num_sequences):
    plt.plot(scaled_data[i, :, 0], label=f'Sequence {i+1}')

plt.title("Time Series Data")
plt.xlabel("Time Steps")
plt.ylabel("B.RTD1 Value")
#plt.legend(loc="upper right", bbox_to_anchor=(1.15, 1))
plt.show()

# original_data = scaler.inverse_transform(scaled_data)

# %%
model = tsgm.models.timeGAN.TimeGAN(
    seq_len=24,
    module="gru",
    hidden_dim=24,
    n_features=1,  
    # n_layers=2,
    # n_layers=4,
    n_layers=6,
    batch_size=8,
    gamma=1.0
)


model.compile()
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.

# %%
epochs=1000
# checkpoints_interval = max(1, epochs // 5)
# generate_synthetic = [int(epochs * 0.2), int(epochs * 0.4), int(epochs * 0.6), int(epochs * 0.8), epochs]

model.fit(
    data=scaled_data,
    epochs=epochs
)
# Out:
# Model: "Autoencoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  RealData (InputLayer)       [(8, 24, 1)]              0
#
#  Embedder (Sequential)       (8, 24, 24)               20544
#
#  Recovery (Sequential)       (8, 24, 1)                21625
#
# =================================================================
# Total params: 42169 (164.72 KB)
# Trainable params: 42169 (164.72 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Model: "AdversarialSupervised"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  RandomNoise (InputLayer)    [(8, 24, 1)]              0
#
#  Generator (Sequential)      (8, 24, 24)               20544
#
#  Supervisor (Sequential)     (8, 24, 24)               22200
#
#  Discriminator (Sequential)  (8, 24, 1)                21625
#
# =================================================================
# Total params: 64369 (251.44 KB)
# Trainable params: 64369 (251.44 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Model: "AdversarialEmbedded"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  RandomNoise (InputLayer)    [(8, 24, 1)]              0
#
#  Generator (Sequential)      (8, 24, 24)               20544
#
#  Discriminator (Sequential)  (8, 24, 1)                21625
#
# =================================================================
# Total params: 42169 (164.72 KB)
# Trainable params: 42169 (164.72 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Model: "FinalGenerator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  RandomNoise (InputLayer)    [(8, 24, 1)]              0
#
#  Generator (Sequential)      (8, 24, 24)               20544
#
#  Supervisor (Sequential)     (8, 24, 24)               22200
#
#  Recovery (Sequential)       (8, 24, 1)                21625
#
# =================================================================
# Total params: 64369 (251.44 KB)
# Trainable params: 64369 (251.44 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Model: "FinalDiscriminator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  RealData (InputLayer)       [(8, 24, 1)]              0
#
#  Embedder (Sequential)       (8, 24, 24)               20544
#
#  Discriminator (Sequential)  (8, 24, 1)                21625
#
# =================================================================
# Total params: 42169 (164.72 KB)
# Trainable params: 42169 (164.72 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# INFO:models:Start Embedding Network Training
# Autoencoder - training: 100%|██████████| 1000/1000 [00:13<00:00, 75.09it/s]
# INFO:models:Finished Embedding Network Training
# INFO:models:Start Training with Supervised Loss Only
# Adversarial Supervised - training: 100%|██████████| 1000/1000 [00:10<00:00, 99.86it/s]
# INFO:models:Finished Training with Supervised Loss Only
# INFO:models:Start Joint Training
# GAN with embedding - training:   0%|          | 0/1000 [00:00<?, ?it/s]INFO:models:Train Discriminator (discriminator does not work well yet)
# GAN with embedding - training:   0%|          | 1/1000 [00:14<3:53:20, 14.01s/it]INFO:models:Train Discriminator (discriminator does not work well yet)
# GAN with embedding - training:   0%|          | 2/1000 [00:20<2:40:23,  9.64s/it]INFO:models:Train Discriminator (discriminator does not work well yet)
# GAN with embedding - training:   0%|          | 3/1000 [00:21<1:32:14,  5.55s/it]INFO:models:Train Discriminator (discriminator does not work well yet)
# GAN with embedding - training:   0%|          | 4/1000 [00:24<1:17:24,  4.66s/it]INFO:models:Train Discriminator (discriminator does not work well yet)
# GAN with embedding - training:   0%|          | 5/1000 [00:25<53:43,  3.24s/it]  INFO:models:Train Discriminator (discriminator does not work well yet)
# GAN with embedding - training:   1%|          | 6/1000 [00:25<39:15,  2.37s/it]INFO:models:Train Discriminator (discriminator does not work well yet)
# GAN with embedding - training:   1%|          | 7/1000 [00:26<30:04,  1.82s/it]INFO:models:Train Discriminator (discriminator does not work well yet)
# GAN with embedding - training:   1%|          | 8/1000 [00:27<24:05,  1.46s/it]INFO:models:Train Discriminator (discriminator does not work well yet)
# GAN with embedding - training:   1%|          | 9/1000 [00:28<20:06,  1.22s/it]INFO:models:Train Discriminator (discriminator does not work well yet)
# GAN with embedding - training:   1%|          | 10/1000 [00:28<17:23,  1.05s/it]INFO:models:Train Discriminator (discriminator does not work well yet)
# GAN with embedding - training:   1%|          | 11/1000 [00:29<15:31,  1.06it/s]INFO:models:Train Discriminator (discriminator does not work well yet)
# GAN with embedding - training:   1%|          | 12/1000 [00:30<14:14,  1.16it/s]INFO:models:Train Discriminator (discriminator does not work well yet)
# GAN with embedding - training:   1%|▏         | 13/1000 [00:30<13:20,  1.23it/s]INFO:models:Train Discriminator (discriminator does not work well yet)
# GAN with embedding - training:   1%|▏         | 14/1000 [00:31<12:42,  1.29it/s]INFO:models:Train Discriminator (discriminator does not work well yet)
# GAN with embedding - training:   2%|▏         | 15/1000 [00:32<12:16,  1.34it/s]INFO:models:Train Discriminator (discriminator does not work well yet)
# GAN with embedding - training:   2%|▏         | 16/1000 [00:32<12:00,  1.37it/s]INFO:models:Train Discriminator (discriminator does not work well yet)
# GAN with embedding - training:   2%|▏         | 17/1000 [00:33<11:49,  1.39it/s]INFO:models:Train Discriminator (discriminator does not work well yet)
# GAN with embedding - training:   2%|▏         | 18/1000 [00:34<11:43,  1.40it/s]INFO:models:Train Discriminator (discriminator does not work well yet)
# GAN with embedding - training:   2%|▏         | 19/1000 [00:34<11:36,  1.41it/s]INFO:models:Train Discriminator (discriminator does not work well yet)
# GAN with embedding - training:   2%|▏         | 20/1000 [00:35<11:29,  1.42it/s]INFO:models:Train Discriminator (discriminator does not work well yet)
# GAN with embedding - training:   2%|▏         | 21/1000 [00:36<11:25,  1.43it/s]INFO:models:Train Discriminator (discriminator does not work well yet)
# GAN with embedding - training:   2%|▏         | 22/1000 [00:37<11:28,  1.42it/s]INFO:models:Train Discriminator (discriminator does not work well yet)
# GAN with embedding - training:   2%|▏         | 23/1000 [00:37<11:24,  1.43it/s]INFO:models:Train Discriminator (discriminator does not work well yet)
# GAN with embedding - training:   2%|▏         | 24/1000 [00:38<11:22,  1.43it/s]INFO:models:Train Discriminator (discriminator does not work well yet)
# GAN with embedding - training:   2%|▎         | 25/1000 [00:39<11:18,  1.44it/s]INFO:models:Train Discriminator (discriminator does not work well yet)
# GAN with embedding - training:   3%|▎         | 26/1000 [00:39<11:16,  1.44it/s]INFO:models:Train Discriminator (discriminator does not work well yet)
# GAN with embedding - training:   3%|▎         | 27/1000 [00:40<11:14,  1.44it/s]INFO:models:Train Discriminator (discriminator does not work well yet)
# GAN with embedding - training:   3%|▎         | 28/1000 [00:41<11:12,  1.45it/s]INFO:models:Train Discriminator (discriminator does not work well yet)
# GAN with embedding - training:   3%|▎         | 29/1000 [00:41<11:11,  1.45it/s]INFO:models:Train Discriminator (discriminator does not work well yet)
# GAN with embedding - training:   3%|▎         | 30/1000 [00:42<11:10,  1.45it/s]INFO:models:Train Discriminator (discriminator does not work well yet)
# GAN with embedding - training:   3%|▎         | 31/1000 [00:43<11:09,  1.45it/s]INFO:models:Train Discriminator (discriminator does not work well yet)
# GAN with embedding - training:   3%|▎         | 32/1000 [00:43<11:08,  1.45it/s]INFO:models:Train Discriminator (discriminator does not work well yet)
# GAN with embedding - training:   3%|▎         | 33/1000 [00:44<11:08,  1.45it/s]INFO:models:Train Discriminator (discriminator does not work well yet)
# GAN with embedding - training:   3%|▎         | 34/1000 [00:45<11:07,  1.45it/s]INFO:models:Train Discriminator (discriminator does not work well yet)
# GAN with embedding - training:   4%|▎         | 35/1000 [00:46<11:07,  1.45it/s]INFO:models:Train Discriminator (discriminator does not work well yet)
# GAN with embedding - training:   4%|▎         | 36/1000 [00:46<11:06,  1.45it/s]INFO:models:Train Discriminator (discriminator does not work well yet)
# GAN with embedding - training:   4%|▎         | 37/1000 [00:47<11:05,  1.45it/s]INFO:models:Train Discriminator (discriminator does not work well yet)
# GAN with embedding - training:   4%|▍         | 38/1000 [00:48<11:04,  1.45it/s]INFO:models:Train Discriminator (discriminator does not work well yet)
# GAN with embedding - training:   4%|▍         | 39/1000 [00:48<11:05,  1.45it/s]INFO:models:Train Discriminator (discriminator does not work well yet)
# GAN with embedding - training:   4%|▍         | 40/1000 [00:49<11:03,  1.45it/s]INFO:models:Train Discriminator (discriminator does not work well yet)
# GAN with embedding - training:   4%|▍         | 41/1000 [00:50<11:07,  1.44it/s]INFO:models:Train Discriminator (discriminator does not work well yet)
# GAN with embedding - training:   4%|▍         | 42/1000 [00:50<11:05,  1.44it/s]INFO:models:Train Discriminator (discriminator does not work well yet)
# GAN with embedding - training:   4%|▍         | 43/1000 [00:51<11:04,  1.44it/s]INFO:models:Train Discriminator (discriminator does not work well yet)
# GAN with embedding - training:   4%|▍         | 44/1000 [00:52<11:08,  1.43it/s]INFO:models:Train Discriminator (discriminator does not work well yet)
# GAN with embedding - training:   4%|▍         | 45/1000 [00:52<11:06,  1.43it/s]INFO:models:Train Discriminator (discriminator does not work well yet)
# GAN with embedding - training:   5%|▍         | 46/1000 [00:53<11:03,  1.44it/s]INFO:models:Train Discriminator (discriminator does not work well yet)
# GAN with embedding - training:   5%|
fig, axes = plt.subplots(1, 2, figsize=(15, 6))

# Plot original data
for i in range(28):
    axes[0].plot(scaled_data[i, :, 0])
axes[0].set_title("Original Data ")
axes[0].set_xlabel("Time Steps")
axes[0].set_ylabel("Normalized Value")
# axes[0].legend()

# Plot synthetic data
for i in range(ns):
    axes[1].plot(new_x[i, :, 0])
axes[1].set_title("Generated Synthetic Data")
axes[1].set_xlabel("Time Steps")
axes[1].set_ylabel("Feature Value")
# axes[1].set_ylim(12, 30)  # Set y-axis limits

plt.tight_layout()
plt.show()
# Out:
# Synthetic data generation: 100%|██████████| 4/4 [00:01<00:00,  3.97it/s]

# %%
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
import numpy as np

# Reshape the data for PCA and t-SNE
num_sequences = scaled_data.shape[0]
time_steps = scaled_data.shape[1]
features = scaled_data.shape[2]

# Flatten the time-series data for PCA and t-SNE
scaled_data_flattened = scaled_data.reshape(num_sequences, -1)
synthetic_flattened = synthetic.reshape(num_sequences, -1)

# Combine original and synthetic data for joint visualization
combined_data = np.vstack((scaled_data_flattened, synthetic_flattened))
labels = np.array([0] * num_sequences + [1] * num_sequences)  # 0 for original, 1 for synthetic

# PCA
pca = PCA(n_components=2)
pca_result = pca.fit_transform(combined_data)

# t-SNE
tsne = TSNE(n_components=2, perplexity=30, n_iter=300, random_state=0)
tsne_result = tsne.fit_transform(combined_data)

# Plot PCA and t-SNE with different shapes
fig, axes = plt.subplots(1, 2, figsize=(15, 6))

# PCA plot with different shapes
axes[0].scatter(pca_result[labels == 0, 0], pca_result[labels == 0, 1], 
                label="Original Data", alpha=0.5, marker='o')  # Circle marker for original data
axes[0].scatter(pca_result[labels == 1, 0], pca_result[labels == 1, 1], 
                label="Synthetic Data", alpha=0.5, marker='s')  # Square marker for synthetic data
axes[0].set_title("PCA of Original vs Synthetic Data")
axes[0].set_xlabel("PCA Component 1")
axes[0].set_ylabel("PCA Component 2")
axes[0].legend()

# t-SNE plot with different shapes
axes[1].scatter(tsne_result[labels == 0, 0], tsne_result[labels == 0, 1], 
                label="Original Data", alpha=0.5, marker='o')  # Circle marker for original data
axes[1].scatter(tsne_result[labels == 1, 0], tsne_result[labels == 1, 1], 
                label="Synthetic Data", alpha=0.5, marker='s')  # Square marker for synthetic data
axes[1].set_title("t-SNE of Original vs Synthetic Data")
axes[1].set_xlabel("t-SNE Component 1")
axes[1].set_ylabel("t-SNE Component 2")
axes[1].legend()

plt.tight_layout()
plt.show()

# %%
ns = 1
new_x = model.generate(n_samples=ns)

num_sequences = new_x.shape[0]  # Number of sequences to plot
synthetic = scaler.inverse_transform(new_x)
fig, axes = plt.subplots(1, 2, figsize=(15, 6))

# Plot original data
for i in range(28):
    axes[0].plot(scaled_data[i, :, 0])
axes[0].set_title("Original Data ")
axes[0].set_xlabel("Time Steps")
axes[0].set_ylabel("Normalized Value")
# axes[0].legend()

# Plot synthetic data
for i in range(ns):
    axes[1].plot(new_x[i, :, 0])
axes[1].set_title("Generated Synthetic Data")
axes[1].set_xlabel("Time Steps")
axes[1].set_ylabel("Feature Value")
axes[1].set_ylim(12, 30)  # Set y-axis limits

plt.tight_layout()
plt.show()
# Out:
# Synthetic data generation: 100%|██████████| 1/1 [00:00<00:00,  3.59it/s]

# %% [markdown]
# # Optuna example
# https://github.com/AlexanderVNikitin/tsgm/blob/main/tutorials/Model%20Selection.ipynb
