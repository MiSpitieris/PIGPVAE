# %%
# Import necessary libraries
import torch
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from torch.utils.data import Dataset, DataLoader


import tsgm
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

# %%
file_path = '../Data/RICO4_Dataset_processed.hdf'
df = pd.read_hdf(file_path)

# %%
df_c = df[df['temp_change_class'] == 'c']
def select_points(group):
    return group.iloc[::10]  # Select every 10th row
df_c = df_c.groupby('Scheduler Step').apply(select_points).reset_index(drop=True)
# Out:
# /var/folders/46/30710m094qv2_dhfs08nzzd00000gn/T/ipykernel_70728/1438173926.py:4: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_c = df_c.groupby('Scheduler Step').apply(select_points).reset_index(drop=True)

# %%
df_c = df_c[['B.RTD1','time_within_interval','interval']]

# %%
# Initialize a list to collect each time series sequence
sequences = []

# Set the desired sequence length
seq_len = 24

# Group by each unique interval
for _, group in df_c.groupby('interval'):
    # Select B.RTD1 values as the time series data
    sequence = group['B.RTD1'].values
    
    # Truncate or pad the sequence to ensure it has exactly 24 time steps
    if len(sequence) >= seq_len:
        sequence = sequence[:seq_len]
    else:
        sequence = np.pad(sequence, (0, seq_len - len(sequence)), 'constant', constant_values=0)
    
    # Append the sequence as a new entry in the list
    sequences.append(sequence)

# Convert the list of sequences to a DataFrame
df_sequences = pd.DataFrame(sequences)
sequences_array = df_sequences.to_numpy()
sequences_array = sequences_array.reshape((sequences_array.shape[0], sequences_array.shape[1], 1))
data=sequences_array

validation_ratio = 0.3  # 20% for validation

# Split data into training and validation sets
train_data, val_data = train_test_split(data, test_size=validation_ratio, random_state=42)

print("Training data shape:", train_data.shape)
print("Validation data shape:", val_data.shape)
# Out:
# Training data shape: (19, 24, 1)
# Validation data shape: (9, 24, 1)

# %%
scaler = tsgm.utils.TSFeatureWiseScaler()        
scaled_train_data = scaler.fit_transform(train_data)

# Plot for the first feature
num_sequences = scaled_train_data.shape[0]

plt.figure(figsize=(12, 8))
for i in range(num_sequences):
    plt.plot(scaled_train_data[i, :, 0], label=f'Sequence {i+1}')

plt.title("Time Series Data")
plt.xlabel("Time Steps")
plt.ylabel("B.RTD1 Value")
#plt.legend(loc="upper right", bbox_to_anchor=(1.15, 1))
plt.show()

# original_data = scaler.inverse_transform(scaled_data)

# %%
model = tsgm.models.timeGAN.TimeGAN(
    seq_len=24,
    module="gru",
    hidden_dim=24,
    n_features=1,  
    n_layers=2,
    batch_size=8,
    gamma=1.0
)


model.compile()
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.

# %%
epochs=1000
# checkpoints_interval = max(1, epochs // 5)
# generate_synthetic = [int(epochs * 0.2), int(epochs * 0.4), int(epochs * 0.6), int(epochs * 0.8), epochs]

model.fit(
    data=scaled_train_data,
    epochs=epochs
)
# Out:
# Model: "Autoencoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  RealData (InputLayer)       [(8, 24, 1)]              0
#
#  Embedder (Sequential)       (8, 24, 24)               6144
#
#  Recovery (Sequential)       (8, 24, 1)                7225
#
# =================================================================
# Total params: 13369 (52.22 KB)
# Trainable params: 13369 (52.22 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Model: "AdversarialSupervised"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  RandomNoise (InputLayer)    [(8, 24, 1)]              0
#
#  Generator (Sequential)      (8, 24, 24)               6144
#
#  Supervisor (Sequential)     (8, 24, 24)               7800
#
#  Discriminator (Sequential)  (8, 24, 1)                7225
#
# =================================================================
# Total params: 21169 (82.69 KB)
# Trainable params: 21169 (82.69 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Model: "AdversarialEmbedded"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  RandomNoise (InputLayer)    [(8, 24, 1)]              0
#
#  Generator (Sequential)      (8, 24, 24)               6144
#
#  Discriminator (Sequential)  (8, 24, 1)                7225
#
# =================================================================
# Total params: 13369 (52.22 KB)
# Trainable params: 13369 (52.22 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Model: "FinalGenerator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  RandomNoise (InputLayer)    [(8, 24, 1)]              0
#
#  Generator (Sequential)      (8, 24, 24)               6144
#
#  Supervisor (Sequential)     (8, 24, 24)               7800
#
#  Recovery (Sequential)       (8, 24, 1)                7225
#
# =================================================================
# Total params: 21169 (82.69 KB)
# Trainable params: 21169 (82.69 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Model: "FinalDiscriminator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  RealData (InputLayer)       [(8, 24, 1)]              0
#
#  Embedder (Sequential)       (8, 24, 24)               6144
#
#  Discriminator (Sequential)  (8, 24, 1)                7225
#
# =================================================================
# Total params: 13369 (52.22 KB)
# Trainable params: 13369 (52.22 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# INFO:models:Start Embedding Network Training
# Autoencoder - training: 100%|██████████| 1000/1000 [00:04<00:00, 209.69it/s]
# INFO:models:Finished Embedding Network Training
# INFO:models:Start Training with Supervised Loss Only
# Adversarial Supervised - training: 100%|██████████| 1000/1000 [00:03<00:00, 253.01it/s]
# INFO:models:Finished Training with Supervised Loss Only
# INFO:models:Start Joint Training
# GAN with embedding - training:   0%|          | 0/1000 [00:00<?, ?it/s]INFO:models:Train Discriminator (discriminator does not work well yet)
# GAN with embedding - training:   0%|          | 1/1000 [00:07<2:08:13,  7.70s/it]INFO:models:Train Discriminator (discriminator does not work well yet)
# GAN with embedding - training:   0%|          | 2/1000 [00:07<55:28,  3.34s/it]  INFO:models:Train Discriminator (discriminator does not work well yet)
# GAN with embedding - training:   0%|          | 3/1000 [00:08<32:08,  1.93s/it]INFO:models:Train Discriminator (discriminator does not work well yet)
# GAN with embedding - training:   0%|          | 4/1000 [00:08<21:12,  1.28s/it]INFO:models:Train Discriminator (discriminator does not work well yet)
# GAN with embedding - training:   0%|          | 5/1000 [00:08<15:12,  1.09it/s]INFO:models:Train Discriminator (discriminator does not work well yet)
# GAN with embedding - training:   1%|          | 6/1000 [00:09<11:32,  1.44it/s]INFO:models:Train Discriminator (discriminator does not work well yet)
# GAN with embedding - training:   1%|          | 7/1000 [00:09<09:17,  1.78it/s]INFO:models:Train Discriminator (discriminator does not work well yet)
# GAN with embedding - training:   1%|          | 8/1000 [00:09<07:47,  2.12it/s]INFO:models:Train Discriminator (discriminator does not work well yet)
# GAN with embedding - training:   1%|          | 9/1000 [00:09<06:45,  2.45it/s]INFO:models:Train Discriminator (discriminator does not work well yet)
# GAN with embedding - training:   1%|          | 10/1000 [00:10<06:02,  2.73it/s]INFO:models:Train Discriminator (discriminator does not work well yet)
# GAN with embedding - training:   1%|          | 11/1000 [00:10<05:34,  2.96it/s]INFO:models:Train Discriminator (discriminator does not work well yet)
# GAN with embedding - training:   1%|          | 12/1000 [00:10<05:14,  3.14it/s]INFO:models:Train Discriminator (discriminator does not work well yet)
# GAN with embedding - training:   1%|▏         | 13/1000 [00:10<04:59,  3.29it/s]INFO:models:Train Discriminator (discriminator does not work well yet)
# GAN with embedding - training:   1%|▏         | 14/1000 [00:11<04:53,  3.36it/s]INFO:models:Train Discriminator (discriminator does not work well yet)
# GAN with embedding - training:   2%|▏         | 15/1000 [00:11<04:44,  3.46it/s]INFO:models:Train Discriminator (discriminator does not work well yet)
# GAN with embedding - training:   2%|▏         | 16/1000 [00:11<04:38,  3.53it/s]INFO:models:Train Discriminator (discriminator does not work well yet)
# GAN with embedding - training:   2%|▏         | 17/1000 [00:12<04:33,  3.59it/s]INFO:models:Train Discriminator (discriminator does not work well yet)
# GAN with embedding - training:   2%|▏         | 18/1000 [00:12<04:30,  3.62it/s]INFO:models:Train Discriminator (discriminator does not work well yet)
# GAN with embedding - training:   2%|▏         | 19/1000 [00:12<04:32,  3.60it/s]INFO:models:Train Discriminator (discriminator does not work well yet)
# GAN with embedding - training:   2%|▏         | 20/1000 [00:12<04:33,  3.59it/s]INFO:models:Train Discriminator (discriminator does not work well yet)
# GAN with embedding - training:   2%|▏         | 21/1000 [00:13<04:34,  3.57it/s]INFO:models:Train Discriminator (discriminator does not work well yet)
# GAN with embedding - training:   2%|▏         | 22/1000 [00:13<04:39,  3.50it/s]INFO:models:Train Discriminator (discriminator does not work well yet)
# GAN with embedding - training:   2%|▏         | 23/1000 [00:13<04:41,  3.47it/s]INFO:models:Train Discriminator (discriminator does not work well yet)
# GAN with embedding - training:   2%|▏         | 24/1000 [00:14<04:37,  3.52it/s]INFO:models:Train Discriminator (discriminator does not work well yet)
# GAN with embedding - training:   2%|▎         | 25/1000 [00:14<04:33,  3.56it/s]INFO:models:Train Discriminator (discriminator does not work well yet)
# GAN with embedding - training:   3%|▎         | 26/1000 [00:14<04:33,  3.56it/s]INFO:models:Train Discriminator (discriminator does not work well yet)
# GAN with embedding - training:   3%|▎         | 27/1000 [00:14<04:32,  3.58it/s]INFO:models:Train Discriminator (discriminator does not work well yet)
# GAN with embedding - training:   3%|▎         | 28/1000 [00:15<04:32,  3.57it/s]INFO:models:Train Discriminator (discriminator does not work well yet)
# GAN with embedding - training:   3%|▎         | 29/1000 [00:15<04:29,  3.60it/s]INFO:models:Train Discriminator (discriminator does not work well yet)
# GAN with embedding - training:   3%|▎         | 30/1000 [00:15<04:28,  3.62it/s]INFO:models:Train Discriminator (discriminator does not work well yet)
# GAN with embedding - training:   3%|▎         | 31/1000 [00:15<04:27,  3.63it/s]INFO:models:Train Discriminator (discriminator does not work well yet)
# GAN with embedding - training:   3%|▎         | 32/1000 [00:16<04:27,  3.62it/s]INFO:models:Train Discriminator (discriminator does not work well yet)
# GAN with embedding - training:   3%|▎         | 33/1000 [00:16<04:25,  3.65it/s]INFO:models:Train Discriminator (discriminator does not work well yet)
# GAN with embedding - training:   3%|▎         | 34/1000 [00:16<04:26,  3.63it/s]INFO:models:Train Discriminator (discriminator does not work well yet)
# GAN with embedding - training:   4%|▎         | 35/1000 [00:17<04:25,  3.64it/s]INFO:models:Train Discriminator (discriminator does not work well yet)
# GAN with embedding - training:   4%|▎         | 36/1000 [00:17<04:26,  3.62it/s]INFO:models:Train Discriminator (discriminator does not work well yet)
# GAN with embedding - training:   4%|▎         | 37/1000 [00:17<04:25,  3.63it/s]INFO:models:Train Discriminator (discriminator does not work well yet)
# GAN with embedding - training:   4%|▍         | 38/1000 [00:18<05:22,  2.98it/s]INFO:models:Train Discriminator (discriminator does not work well yet)
# GAN with embedding - training:   4%|▍         | 39/1000 [00:18<05:06,  3.14it/s]INFO:models:Train Discriminator (discriminator does not work well yet)
# GAN with embedding - training:   4%|▍         | 40/1000 [00:18<04:54,  3.26it/s]INFO:models:Train Discriminator (discriminator does not work well yet)
# GAN with embedding - training:   4%|▍         | 41/1000 [00:18<04:45,  3.35it/s]INFO:models:Train Discriminator (discriminator does not work well yet)
# GAN with embedding - training:   4%|▍         | 42/1000 [00:19<04:40,  3.42it/s]INFO:models:Train Discriminator (discriminator does not work well yet)
# GAN with embedding - training:   4%|▍         |
  3.16it/s]INFO:models:Train Discriminator (discriminator does not work well yet)
# GAN with embedding - training:  96%|█████████▋| 963/1000 [05:08<00:11,  3.16it/s]INFO:models:Train Discriminator (discriminator does not work well yet)
# GAN with embedding - training:  96%|█████████▋| 964/1000 [05:08<00:11,  3.16it/s]INFO:models:Train Discriminator (discriminator does not work well yet)
# GAN with embedding - training:  96%|█████████▋| 965/1000 [05:09<00:11,  3.16it/s]INFO:models:Train Discriminator (discriminator does not work well yet)
# GAN with embedding - training:  97%|█████████▋| 966/1000 [05:09<00:10,  3.17it/s]INFO:models:Train Discriminator (discriminator does not work well yet)
# GAN with embedding - training:  97%|█████████▋| 967/1000 [05:09<00:10,  3.17it/s]INFO:models:Train Discriminator (discriminator does not work well yet)
# GAN with embedding - training:  97%|█████████▋| 968/1000 [05:10<00:10,  3.17it/s]INFO:models:Train Discriminator (discriminator does not work well yet)
# GAN with embedding - training:  97%|█████████▋| 969/1000 [05:10<00:09,  3.18it/s]INFO:models:Train Discriminator (discriminator does not work well yet)
# GAN with embedding - training:  97%|█████████▋| 970/1000 [05:10<00:09,  3.18it/s]INFO:models:Train Discriminator (discriminator does not work well yet)
# GAN with embedding - training:  97%|█████████▋| 971/1000 [05:11<00:09,  3.18it/s]INFO:models:Train Discriminator (discriminator does not work well yet)
# GAN with embedding - training:  97%|█████████▋| 972/1000 [05:11<00:08,  3.17it/s]INFO:models:Train Discriminator (discriminator does not work well yet)
# GAN with embedding - training:  97%|█████████▋| 973/1000 [05:11<00:08,  3.04it/s]INFO:models:Train Discriminator (discriminator does not work well yet)
# GAN with embedding - training:  97%|█████████▋| 974/1000 [05:12<00:08,  3.08it/s]INFO:models:Train Discriminator (discriminator does not work well yet)
# GAN with embedding - training:  98%|█████████▊| 975/1000 [05:12<00:08,  3.11it/s]INFO:models:Train Discriminator (discriminator does not work well yet)
# GAN with embedding - training:  98%|█████████▊| 976/1000 [05:12<00:07,  3.10it/s]INFO:models:Train Discriminator (discriminator does not work well yet)
# GAN with embedding - training:  98%|█████████▊| 977/1000 [05:13<00:07,  3.08it/s]INFO:models:Train Discriminator (discriminator does not work well yet)
# GAN with embedding - training:  98%|█████████▊| 978/1000 [05:13<00:07,  3.10it/s]INFO:models:Train Discriminator (discriminator does not work well yet)
# GAN with embedding - training:  98%|█████████▊| 979/1000 [05:13<00:06,  3.11it/s]INFO:models:Train Discriminator (discriminator does not work well yet)
# GAN with embedding - training:  98%|█████████▊| 980/1000 [05:13<00:06,  3.12it/s]INFO:models:Train Discriminator (discriminator does not work well yet)
# GAN with embedding - training:  98%|█████████▊| 981/1000 [05:14<00:06,  3.08it/s]INFO:models:Train Discriminator (discriminator does not work well yet)
# GAN with embedding - training:  98%|█████████▊| 982/1000 [05:14<00:05,  3.09it/s]INFO:models:Train Discriminator (discriminator does not work well yet)
# GAN with embedding - training:  98%|█████████▊| 983/1000 [05:14<00:05,  3.09it/s]INFO:models:Train Discriminator (discriminator does not work well yet)
# GAN with embedding - training:  98%|█████████▊| 984/1000 [05:15<00:05,  3.08it/s]INFO:models:Train Discriminator (discriminator does not work well yet)
# GAN with embedding - training:  98%|█████████▊| 985/1000 [05:15<00:04,  3.08it/s]INFO:models:Train Discriminator (discriminator does not work well yet)
# GAN with embedding - training:  99%|█████████▊| 986/1000 [05:15<00:04,  3.06it/s]INFO:models:Train Discriminator (discriminator does not work well yet)
# GAN with embedding - training:  99%|█████████▊| 987/1000 [05:16<00:04,  3.07it/s]INFO:models:Train Discriminator (discriminator does not work well yet)
# GAN with embedding - training:  99%|█████████▉| 988/1000 [05:16<00:03,  3.08it/s]INFO:models:Train Discriminator (discriminator does not work well yet)
# GAN with embedding - training:  99%|█████████▉| 989/1000 [05:16<00:03,  3.00it/s]INFO:models:Train Discriminator (discriminator does not work well yet)
# GAN with embedding - training:  99%|█████████▉| 990/1000 [05:17<00:03,  3.01it/s]INFO:models:Train Discriminator (discriminator does not work well yet)
# GAN with embedding - training:  99%|█████████▉| 991/1000 [05:17<00:02,  3.01it/s]INFO:models:Train Discriminator (discriminator does not work well yet)
# GAN with embedding - training:  99%|█████████▉| 992/1000 [05:17<00:02,  3.01it/s]INFO:models:Train Discriminator (discriminator does not work well yet)
# GAN with embedding - training:  99%|█████████▉| 993/1000 [05:18<00:02,  3.05it/s]INFO:models:Train Discriminator (discriminator does not work well yet)
# GAN with embedding - training:  99%|█████████▉| 994/1000 [05:18<00:01,  3.07it/s]INFO:models:Train Discriminator (discriminator does not work well yet)
# GAN with embedding - training: 100%|█████████▉| 995/1000 [05:18<00:01,  3.09it/s]INFO:models:Train Discriminator (discriminator does not work well yet)
# GAN with embedding - training: 100%|█████████▉| 996/1000 [05:19<00:01,  3.09it/s]INFO:models:Train Discriminator (discriminator does not work well yet)
# GAN with embedding - training: 100%|█████████▉| 997/1000 [05:19<00:00,  3.11it/s]INFO:models:Train Discriminator (discriminator does not work well yet)
# GAN with embedding - training: 100%|█████████▉| 998/1000 [05:19<00:00,  3.10it/s]INFO:models:Train Discriminator (discriminator does not work well yet)
# GAN with embedding - training: 100%|█████████▉| 999/1000 [05:20<00:00,  3.11it/s]INFO:models:Train Discriminator (discriminator does not work well yet)
# GAN with embedding - training: 100%|██████████| 1000/1000 [05:20<00:00,  3.12it/s]
# INFO:models:Finished Joint Training

# %%
original_data = scaler.inverse_transform(scaled_train_data)

# %%
ns = train_data.shape[0]
new_x = model.generate(n_samples=ns)

num_sequences = new_x.shape[0]  # Number of sequences to plot
synthetic = scaler.inverse_transform(new_x)
fig, axes = plt.subplots(1, 2, figsize=(15, 6))

# Plot original data
for i in range(ns):
    axes[0].plot(scaled_train_data[i, :, 0])
axes[0].set_title("Original Data ")
axes[0].set_xlabel("Time Steps")
axes[0].set_ylabel("Normalized Value")
axes[0].set_ylim(12, 30)

# Plot synthetic data
for i in range(ns):
    axes[1].plot(new_x[i, :, 0])
axes[1].set_title("Generated Synthetic Data")
axes[1].set_xlabel("Time Steps")
axes[1].set_ylabel("Feature Value")
axes[1].set_ylim(12, 30)  # Set y-axis limits

plt.tight_layout()
plt.show()
# Out:
# Synthetic data generation: 100%|██████████| 3/3 [00:00<00:00,  9.43it/s]

# %%
import dill

# Save the model with dill
with open('pre_trained_models/timegan_cooling.pkl', 'wb') as f:
    dill.dump(model, f)

# Load the model with dill
with open('pre_trained_models/timegan_cooling.pkl', 'rb') as f:
    loaded_model = dill.load(f)

# %%
# loaded_model.generate(n_samples=ns)

# %%
scaler.mins
# Out:
# array([14.2])

# %%
scaler.maxs
# Out:
# array([29.9])

# %%
new_s = model.generate(n_samples=ns)
# Out:
# Synthetic data generation: 100%|██████████| 3/3 [00:00<00:00,  9.22it/s]

# %%
